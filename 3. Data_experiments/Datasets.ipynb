# %% [markdown]
# # Enterprises that use AI Worldwide

# %%
import pandas as pd
Enterprises = pd.read_csv("C:/Users/Jhonnatan/Documents/GitHub/Impact-of-AI-in-organizations/Datasets/EnterpriseAI.csv")
Enterprises.head()
# Out:
#                 Name             Url  Total Funding Funding Stage  \
# 0  NetBase Solutions     netbase.com     84600000.0    Late Stage
# 1         Salesforce  salesforce.com    102910000.0    Late Stage
# 2             GumGum      gumgum.com     36825000.0      Series C
# 3         Lexalytics  lexalytics.com            0.0   None Listed
# 4          FusionOps   fusionops.com     43656544.0      Series C
#
#                                          Description  Year Founded  \
# 0  With the NetBase real-time social media monito...        2004.0
# 1  Salesforce is the Customer Success Platform. O...        1999.0
# 2  GumGum’s mission is to add value to every onli...        2008.0
# 3  Text Analytics & Survey Analysis with highly c...        2003.0
# 4  Mine the world’s information and makes it acti...        1999.0
#
#   Exit Status                       Location State Employees  \
# 0     Private  Mountain View, California, CA    CA       140
# ...

# %% [markdown]
# # AI Tools

# %%
import pandas as pd
tools = pd.read_csv("C:/Users/Jhonnatan/Documents/GitHub/Impact-of-AI-in-organizations/Datasets/aitools.csv")
tools.head()
#tools.describe()
# Out:
#                                        tool_mage_url  \
# 0  https://uploads-ssl.webflow.com/63994dae103371...
# 1  https://uploads-ssl.webflow.com/63994dae103371...
# 2  https://uploads-ssl.webflow.com/63994dae103371...
# 3  https://uploads-ssl.webflow.com/63994dae103371...
# 4  https://uploads-ssl.webflow.com/63994dae103371...
#
#                         tool  \
# 0                    Codeium
# 1                    LeiaPix
# 2  GPT-3 Playground (OpenAI)
# 3                 BlueWillow
# 4               Character.AI
#
#                                     tool_description           category  \
# 0  Helps developers understand, modify, and test ...    Generative Code
# 1    Upload an image and turn it into a 3D animation  Image Improvement
# 2  Free AI writing tool - Let the AI generate any...        Copywriting
# 3        AI-powered image generating tool in Discord     Generative Art
# 4         Have chat conversations with AI characters               Chat
#
# ...

# %%
import pandas as pd
tools_2 = pd.read_csv("C:/Users/Jhonnatan/Documents/GitHub/Impact-of-AI-in-organizations/Datasets/futuretools.csv")
tools_2.head()
# tools_2.describe()
# Out:
#                                        tool_mage_url            tool  \
# 0  https://global-uploads.webflow.com/63994dae103...  Inbox Narrator
# 1  https://global-uploads.webflow.com/63994dae103...        ChatTube
# 2  https://global-uploads.webflow.com/63994dae103...            Bito
# 3  https://global-uploads.webflow.com/63994dae103...        Bagasura
# 4  https://global-uploads.webflow.com/63994dae103...    CometCore AI
#
#                                     tool_description        category  upvotes  \
# 0  An app for email summaries delivered by a voic...    Productivity        1
# 1  A Google Chrome Extension to chat with any you...            Chat        5
# 2  A tool to generate custom designs for any proj...  Generative Art        3
# 3  A platform for bug tracking, streamlining work...    Productivity        2
# 4  A chat platform for automating tasks and creat...            Chat       10
#
#   tags
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %% [markdown]
# # AI info French Govermment

# %%
import pandas as pd
research = pd.read_excel("C:/Users/Jhonnatan/Documents/GitHub/Impact-of-AI-in-organizations/Datasets/AI_eco_gouvFR.xlsx")
research.head()
#research.describe()
# Out:
#                                                title  \
# 0                                           Biocides
# 1  Transformation numérique : les aides aux entre...
# 2                                      Rapports 2023
# 3  Diversité et égalité des chances : Bercy accue...
# 4  Les enjeux de propriété intellectuelle dans l'...
#
#                                          description  \
# 0  modifiant la directive 98/8/CE du Parlement eu...
# 1  Francenum.gouv.fr propose des conseils concern...
# 2  l'industrie de la santé chez Dassault Systèmes...
# 3  Besoin en compétences : comment l'immigration ...
# 4  Les enjeux de propriété intellectuelle dans l'...
#
#                                                  URL
# 0  https://www.economie.gouv.fr/dgccrf/publicatio...
# 1  https://www.economie.gouv.fr/cedef/aides-numer...
# 2      https://www.economie.gouv.fr/cge/rapports2023
# 3  https://www.economie.gouv.fr/sommet-inclusion-...
# 4  https://www.economie.gouv.fr/apie/les-enjeux-d...

# %%
# Azure Text analysis API

# %% [markdown]
# # AI Research on France

# %%
import pandas as pd
research = pd.read_csv("C:/Users/Jhonnatan/Documents/GitHub/Impact-of-AI-in-organizations/Datasets/scopus.csv")
research.head()
#research.describe()
# Out:
#                                              Authors  \
# 0                         Ahmad Husairi M.; Rossi P.
# 1  Pagallo U.; O’Sullivan S.; Nevejans N.; Holzin...
# 2  Karapantelakis A.; Alizadeh P.; Alabassi A.; D...
# 3  Beljaards L.; Pezzotti N.; Rao C.; Doneva M.; ...
# 4       Borghesani P.; Herwig N.; Antoni J.; Wang W.
#
#                                    Author full names  \
# 0  Ahmad Husairi, Mariyani (57222988933); Rossi, ...
# 1  Pagallo, Ugo (19337758400); O’Sullivan, Shane ...
# 2  Karapantelakis, Athanasios (35113103400); Aliz...
# 3  Beljaards, Laurens (57219764499); Pezzotti, Ni...
# 4  Borghesani, P. (54929106000); Herwig, N. (5721...
#
#                                         Author(s) ID  \
# 0                           57222988933; 56289040400
# 1  19337758400; 57205361372; 57205364562; 2339628...
# 2  35113103400; 58540431900; 58540313100; 5722251...
# 3  57219764499; 58150639100; 57222130969; 2398862...
# ...

# %%
import pandas as pd
research_AI_BS = pd.read_csv("C:/Users/Jhonnatan/Documents/GitHub/Impact-of-AI-in-organizations/Datasets/scopus_AI_business.csv")
research_AI_BS.head()
research_AI_BS.describe()
# Out:
#               Year    Page start      Page end  Page count    Cited by  \
# count   198.000000    136.000000    135.000000  135.000000  198.000000
# mean   2019.888889   1609.095588   1653.533333   34.451852   21.257576
# std       5.176850   8643.930230   8672.326029   73.350998   54.921534
# min    1991.000000      1.000000      6.000000    2.000000    0.000000
# 25%    2020.000000     67.500000    115.000000    7.000000    0.000000
# 50%    2022.000000    194.000000    260.000000   13.000000    2.500000
# 75%    2023.000000    516.750000    536.000000   22.000000   15.750000
# max    2024.000000  95376.000000  95396.000000  489.000000  411.000000
#
#        Molecular Sequence Numbers  Tradenames  Manufacturers  Conference code  \
# count                         0.0         0.0            0.0        58.000000
# mean                          NaN         NaN            NaN    197291.982759
# std                           NaN         NaN            NaN     59949.320927
# ...

# %% [markdown]
# # AI FR News

# %%
import pandas as pd
DS = pd.read_csv("C:/Users/Jhonnatan/Documents/GitHub/Impact-of-AI-in-organizations/Datasets/news_articles.csv")
DS.head()
# Out:
#                                                Title  \
# 0  AI: Virtual reality, concrete ambitions - Busi...
# 1  Keep an AI on France #1: Overview - Business F...
# 2                   FAQ du Volontariat International
# 3  Keep an AI on France #2: Education - Business ...
# 4  AI France SUMMIT 2020 : l’Intelligence artific...
#
#                                                 Link  \
# 0  https://world.businessfrance.fr/nordic/2023/04...
# 1  https://world.businessfrance.fr/nordic/2019/03...
# 2  https://mon-vie-via.businessfrance.fr/faq-vie-via
# 3  https://world.businessfrance.fr/nordic/2019/03...
# 4  https://www.techtalks.fr/ai-france-summit-2020...
#
#                                          Description Publication Date
# 0  In 2018, France was one of the first countries...              NaN
# 1                                                NaN              NaN
# 2  Contrat, salaire, logement, déplacements, vaca...              NaN
# ...

# %% [markdown]
# # Data Scientist vs size of Datasets (France experiment 2016)

# %%
import pandas as pd
DS = pd.read_csv("C:/Users/Jhonnatan/Documents/GitHub/Impact-of-AI-in-organizations/Datasets/Data_Scientists_France.csv")
DS.head()
# Out:
#    ID DS_1 DS_2    DS_3 DS_4 DS_5    W_1  W_2   W_3  W_4  W_5 W_6        W_7  \
# 0   1   No   No   Large   No  Yes  Intel  Yes  1400    4   32  No     Python
# 1   2   No   No   Large   No   No    AMD   No   800    2   16  No     Python
# 2   3   No   No  Medium   No  Yes  Intel   No  2400    4   24  No          R
# 3   4   No   No   Large   No  Yes  Intel  Yes  1000    2    4  No          R
# 4   5   No  Yes  Medium  Yes  Yes  Intel   No   900    2   12  No  R, Python
#
#       W_8     W_9
# 0  Python  Python
# 1  Python  Python
# 2       R       R
# 3       R       R
# 4       R       R
