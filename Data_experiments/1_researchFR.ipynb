# %% [markdown]
# # AI Research on France

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
import re

# %%
research = pd.read_csv("C:/Users/Jhonnatan/Documents/GitHub/Impact-of-AI-in-organizations/Datasets/scopus.csv")
research.head()
# Out:
#                                              Authors  \
# 0                         Ahmad Husairi M.; Rossi P.
# 1  Pagallo U.; O’Sullivan S.; Nevejans N.; Holzin...
# 2  Karapantelakis A.; Alizadeh P.; Alabassi A.; D...
# 3  Beljaards L.; Pezzotti N.; Rao C.; Doneva M.; ...
# 4                                           Gross F.
#
#                                    Author full names  \
# 0  Ahmad Husairi, Mariyani (57222988933); Rossi, ...
# 1  Pagallo, Ugo (19337758400); O’Sullivan, Shane ...
# 2  Karapantelakis, Athanasios (35113103400); Aliz...
# 3  Beljaards, Laurens (57219764499); Pezzotti, Ni...
# 4                      Gross, Fridolin (56924689000)
#
#                                         Author(s) ID  \
# 0                           57222988933; 56289040400
# 1  19337758400; 57205361372; 57205364562; 5721027...
# 2  35113103400; 58540431900; 58540313100; 5722251...
# 3  57219764499; 58150639100; 57222130969; 2398862...
# 4                                        56924689000
#
#                                                Title  Year  \
# 0  Delegation of purchasing tasks to AI: The role...  2024
# 1  The underuse of AI in the health sector: Oppor...  2024
# 2         Generative AI in mobile networks: a survey  2024
# 3  AI-based motion artifact severity estimation i...  2024
# 4  The Explanatory Role of Machine Learning in Mo...  2024
#
#                                         Source title Volume Issue Art. No.  \
# 0                           Decision Support Systems    179   NaN   114166
# 1                              Health and Technology     14     1      NaN
# 2  Annales des Telecommunications/Annals of Telec...     79   1-2      NaN
# 3                                    Medical Physics    NaN   NaN      NaN
# 4                                         Erkenntnis    NaN   NaN      NaN
#
#   Page start  ... ISBN  CODEN  PubMed ID Language of Original Document  \
# 0        NaN  ...  NaN  DSSYD        NaN                       English
# 1          1  ...  NaN    NaN        NaN                       English
# 2         15  ...  NaN  ANTEA        NaN                       English
# 3        NaN  ...  NaN  MPHYA        NaN                       English
# 4        NaN  ...  NaN    NaN        NaN                       English
#
#   Abbreviated Source Title Document Type Publication Stage  \
# 0       Decis Support Syst       Article             Final
# 1          Health Technol.        Review             Final
# 2           Ann Telecommun       Article             Final
# 3               Med. Phys.       Article  Article in press
# 4               Erkenntnis       Article  Article in press
#
#                                 Open Access  Source                 EID
# 0                                       NaN  Scopus  2-s2.0-85181774528
# 1  All Open Access; Hybrid Gold Open Access  Scopus  2-s2.0-85179329265
# 2                                       NaN  Scopus  2-s2.0-85168263912
# 3  All Open Access; Hybrid Gold Open Access  Scopus  2-s2.0-85181252141
# 4                                       NaN  Scopus  2-s2.0-85182472773
#
# [5 rows x 46 columns]

# %%
research.describe()
# Out:
#               Year   Page count     Cited by  Conference code     PubMed ID
# count  5251.000000  3689.000000  5245.000000      1800.000000  1.262000e+03
# mean   2020.187964    15.490919    17.172736    188519.479444  3.191747e+07
# std       2.994900    37.783878    84.413153     48552.476035  4.555697e+06
# min    2010.000000   -55.000000     0.000000     81104.000000  1.987689e+07
# 25%    2019.000000     6.000000     0.000000    162272.000000  2.965591e+07
# 50%    2021.000000     9.000000     3.000000    178739.500000  3.275998e+07
# 75%    2022.000000    15.000000    13.000000    194341.000000  3.544193e+07
# max    2024.000000  1057.000000  3183.000000    306689.000000  3.822556e+07

# %% [markdown]
# # Business and AI Research on France

# %%
import pandas as pd
research_bs = pd.read_csv("C:/Users/Jhonnatan/Documents/GitHub/Impact-of-AI-in-organizations/Datasets/scopus_AI_business.csv")
research_bs.head()
data = research_bs

# %%
# Extract descriptions from the 'description' column of the dataframe
documents = research['Abstract'].tolist()
documents = [f'"""{doc}"""' for doc in documents]
#documents

# %% [markdown]
# ### Trend in AI and Machine Learning Research in Business and Management
#
# The graph illustrates the number of publications related to AI and machine learning in business and management per year. It shows a trend in the volume of research in this field, which can be indicative of the growing interest and importance of AI and machine learning in these areas.

# %%
# Filter the dataset for relevant publications (considering all as relevant for now)
# and count the number of publications per year
publication_count = data['Year'].value_counts().sort_index()

# Plotting the trend
plt.figure(figsize=(12, 6))
plt.plot(publication_count.index, publication_count.values, marker='o')
plt.title('Number of Publications Related to AI and Machine Learning in Business and Management Per Year')
plt.xlabel('Year')
plt.ylabel('Number of Publications')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Topics of interest within these publications.
#
# The word cloud visualizes the most frequent terms in the titles of AI and machine learning publications related to business and management. This visualization helps us identify key themes and topics that are prominent in the research.
#
# From the word cloud, we can observe terms that might be associated with the impact points you mentioned, such as "automation," "decision-making," "resource," "planning," and "ethical." This suggests that these areas are indeed focal points in the research on AI and machine learning in the context of work organization.

# %%
# Function to clean and prepare text data
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\d+', '', text)      # Remove numbers
    return text

# Prepare the titles for analysis
titles = data['Title'].dropna().apply(clean_text)

# Combine all titles into a single string
all_titles = ' '.join(titles)

# Create a word frequency dictionary
word_freq = Counter(all_titles.split())

# Create a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# Plotting the word cloud
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Titles in AI and Machine Learning Publications in Business and Management')
plt.show()
